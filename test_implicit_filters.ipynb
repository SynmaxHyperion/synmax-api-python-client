# %%
from synmax.hyperion.hyperion_client import HyperionApiClient, ApiPayload

# %%
# Create a HyperionApiClient object
access_token = "YOUR_ACCESS_KEY"
hyperion_client = HyperionApiClient(access_token=access_token)

# %%
payload = ApiPayload(
    start_date="2024-08-01",
    end_date="2024-09-01"
)

# %%
df = hyperion_client.short_term_forecast(payload=payload)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]INFO:synmax.common.api_client:Payload data: pagination_start=0 start_date=datetime.date(2024, 8, 1) end_date=datetime.date(2024, 9, 1) forecast_run_date=None production_month=None first_production_month_start=None first_production_month_end=None state_code=None region=None sub_region=['Central - TX'] county=None operator=None api=None aggregate_by=[] service_company=None frac_class=None rig_class=None completion_class=None category=None modeled=None
# /Users/felix/Documents/venvs/decoupling_env/lib/python3.11/site-packages/urllib3/connectionpool.py:1063: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hyperion.api.synmax.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# INFO:synmax.common.api_client:Total data size: 109074, total pages to scan: 11
# ...

# %%
df
# Out:
#           date     gas_daily   gas_monthly     oil_daily   oil_monthly  \
# 0   2024-08-01  8.184809e+06  2.537291e+08  1.770566e+06  5.488756e+07
# 1   2024-08-01  6.278004e+06  1.946181e+08  4.491326e+05  1.392311e+07
# 2   2024-08-01  5.922057e+06  1.835838e+08  8.215082e+04  2.546675e+06
# 3   2024-08-01  1.040162e+07  3.224503e+08  9.174133e+04  2.843981e+06
# 4   2024-08-01  3.921491e+06  1.215662e+08  4.286117e+05  1.328696e+07
# ..         ...           ...           ...           ...           ...
# 15  2024-09-01  8.341810e+06  2.502543e+08  3.658664e+04  1.097599e+06
# 16  2024-09-01  3.939145e+06  1.181743e+08  4.273367e+05  1.282010e+07
# 17  2024-09-01  2.614581e+06  7.843744e+07  2.511046e+05  7.533139e+06
# 18  2024-09-01  2.586628e+06  7.759884e+07  1.096145e+06  3.288435e+07
# 19  2024-09-01  1.986782e+07  5.960345e+08  3.035782e+03  9.107347e+04
#
#    state_ab
# 0        NM
# 1        OK
# 2        OH
# 3        LA
# 4        CO
# ..      ...
# 15       WV
# ...
