# %%
from synmax.hyperion.hyperion_client import HyperionApiClient, ApiPayload

# %%
# Create a HyperionApiClient object
access_token = "..."
hyperion_client = HyperionApiClient(access_token=access_token)

# %%
payload = ApiPayload(
    start_date="2024-08-01",
    end_date="2024-09-01"
)

# %%
df = hyperion_client.short_term_forecast(payload=payload)
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]INFO:synmax.common.api_client:Payload data: pagination_start=0 start_date=datetime.date(2024, 8, 1) end_date=datetime.date(2024, 9, 1) forecast_run_date=None production_month=None first_production_month_start=None first_production_month_end=None state_code=None region=None sub_region=['Central - TX'] county=None operator=None api=None aggregate_by=None service_company=None frac_class=None rig_class=None completion_class=None category=None modeled=None
# Fetching data for partition 0 out of 18.
# INFO:synmax.common.api_client:Total data size: 109074, total pages to scan: 11

# %%
df
# Out:
#               api county_name        date forecast_run_date  gas_daily  \
# 0      4200900829      ARCHER  2024-08-01        2024-10-20   0.059355
# 1      4200900829      ARCHER  2024-09-01        2024-10-20   0.061333
# 2      4200900838      ARCHER  2024-08-01        2024-10-20   1.157419
# 3      4200900838      ARCHER  2024-09-01        2024-10-20   1.165333
# 4      4200900840      ARCHER  2024-08-01        2024-10-20   0.326452
# ...           ...         ...         ...               ...        ...
# 45452  4904529500      WESTON  2024-09-01        2024-10-20   4.419427
# 45453  4904529555      WESTON  2024-08-01        2024-10-20  10.787754
# 45454  4904529555      WESTON  2024-09-01        2024-10-20  10.721641
# 45455  4904529634      WESTON  2024-08-01        2024-10-20   2.874876
# 45456  4904529634      WESTON  2024-09-01        2024-10-20   2.716843
#
#        gas_monthly  oil_daily  oil_monthly                    operator_name  \
# 0         1.840000   0.645161    20.000000                CRAMPTON, FREDDIE
# 1         1.840000   0.600000    18.000000                CRAMPTON, FREDDIE
# 2        35.880000   1.064516    33.000000             BRIDWELL OIL COMPANY
# 3        34.960000   1.033333    31.000000             BRIDWELL OIL COMPANY
# 4        10.120000   0.741935    23.000000          SB STREET OPERATING INC
# ...            ...        ...          ...                              ...
# 45452   132.582812   2.591123    77.733683                M & K Oil Company
# 45453   334.420382   3.943568   122.250606                M & K Oil Company
# 45454   321.649239   3.777171   113.315129                M & K Oil Company
# 45455    89.121141   3.125249    96.882715  OILDIGGER RESOURCES FUND l LLLP
# 45456    81.505275   2.871055    86.131656  OILDIGGER RESOURCES FUND l LLLP
#
#       region state_ab    sub_region
# 0       gulf       TX  Central - TX
# 1       gulf       TX  Central - TX
# 2       gulf       TX  Central - TX
# 3       gulf       TX  Central - TX
# 4       gulf       TX  Central - TX
# ...      ...      ...           ...
# 45452   west       WY       Wyoming
# 45453   west       WY       Wyoming
# 45454   west       WY       Wyoming
# 45455   west       WY       Wyoming
# 45456   west       WY       Wyoming
#
# [1340237 rows x 12 columns]
